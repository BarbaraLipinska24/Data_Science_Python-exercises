# %% [markdown]
# <a href="https://colab.research.google.com/github/BarbaraLipinska24/Data_Science_Python-exercises/blob/main/ProjektML/Przewidywanie_cen_aut_u%C5%BCywanych.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

cars_data=pd.read_excel('Car_sales_details.xlsx')

# %%
data=cars_data.copy()

# %%
data.head()
# Out:
#    Index  Price Currency Condition Vehicle_brand Vehicle_model  \
# 0      0  86200      PLN       New        Abarth           595
# 1      1  43500      PLN      Used        Abarth         Other
# 2      2  44900      PLN      Used        Abarth           500
# 3      3  39900      PLN      Used        Abarth           500
# 4      4  97900      PLN       New        Abarth           595
#
#   Vehicle_version Vehicle_generation  Production_year  Mileage_km  ...  \
# 0             NaN                NaN             2021         1.0  ...
# 1             NaN                NaN             1974     59000.0  ...
# 2             NaN                NaN             2018     52000.0  ...
# 3             NaN                NaN             2012     29000.0  ...
# 4             NaN                NaN             2021       600.0  ...
#
#    Dual zone air conditioning  Factory radio GPS navigation  Twilight sensor  \
# 0                           0              0              0                0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208304 entries, 0 to 208303
# Data columns (total 50 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   Index                            208304 non-null  int64
#  1   Price                            208304 non-null  int64
#  2   Currency                         208034 non-null  object
#  3   Condition                        208304 non-null  object
#  4   Vehicle_brand                    208304 non-null  object
#  5   Vehicle_model                    208304 non-null  object
#  6   Vehicle_version                  138082 non-null  object
#  7   Vehicle_generation               147860 non-null  object
#  8   Production_year                  208304 non-null  int64
#  9   Mileage_km                       207321 non-null  float64
#  10  Power_HP                         207661 non-null  float64
# ...

# %%
data.isnull().sum()
# Out:
# Index                                   0
# Price                                   0
# Currency                              270
# Condition                               0
# Vehicle_brand                           0
# Vehicle_model                           0
# Vehicle_version                     70222
# Vehicle_generation                  60444
# Production_year                         0
# Mileage_km                            983
# Power_HP                              643
# Displacement_cm3                     1966
# Fuel_type                               0
# CO2_emissions                      114257
# Drive                               15076
# Transmission                          479
# Type                                    0
# Doors_number                         1487
# Colour                                  0
# Origin_country                      89992
# First_owner                        143210
# First_registration_date            122024
# ...

# %%
data.drop('CO2_emissions', axis=1, inplace=True)
data.drop('First_owner', axis=1, inplace=True)
data.drop('First_registration_date', axis=1, inplace=True)
data.drop('Vehicle_version', axis=1, inplace=True)
data.drop('Vehicle_generation', axis=1, inplace=True)
data.drop('Origin_country', axis=1, inplace=True)
data.drop('Features',axis=1,inplace=True)

# %%
data.isnull().sum()
# Out:
# Index                                  0
# Price                                  0
# Currency                             270
# Condition                              0
# Vehicle_brand                          0
# Vehicle_model                          0
# Production_year                        0
# Mileage_km                           983
# Power_HP                             643
# Displacement_cm3                    1966
# Fuel_type                              0
# Drive                              15076
# Transmission                         479
# Type                                   0
# Doors_number                        1487
# Colour                                 0
# Offer_publication_date                 0
# Offer_location.1                       0
# Offer_location.2                       0
# ABS                                    0
# Central locking                        0
# CD                                     0
# Automatic air conditionin              0
# ...

# %%
data=data.dropna()

# %%
data.isnull().sum()
# Out:
# Index                              0
# Price                              0
# Currency                           0
# Condition                          0
# Vehicle_brand                      0
# Vehicle_model                      0
# Production_year                    0
# Mileage_km                         0
# Power_HP                           0
# Displacement_cm3                   0
# Fuel_type                          0
# Drive                              0
# Transmission                       0
# Type                               0
# Doors_number                       0
# Colour                             0
# Offer_publication_date             0
# Offer_location.1                   0
# Offer_location.2                   0
# ABS                                0
# Central locking                    0
# CD                                 0
# Automatic air conditionin          0
# Electric front windows             0
# Drivers airbag                     0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 189576 entries, 0 to 208300
# Data columns (total 43 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   Index                            189576 non-null  int64
#  1   Price                            189576 non-null  int64
#  2   Currency                         189576 non-null  object
#  3   Condition                        189576 non-null  object
#  4   Vehicle_brand                    189576 non-null  object
#  5   Vehicle_model                    189576 non-null  object
#  6   Production_year                  189576 non-null  int64
#  7   Mileage_km                       189576 non-null  float64
#  8   Power_HP                         189576 non-null  float64
#  9   Displacement_cm3                 189576 non-null  float64
#  10  Fuel_type                        189576 non-null  object
# ...

# %%
data.drop('Offer_publication_date',axis=1,inplace=True)
data.drop('Offer_location.1',axis=1,inplace=True)
data.drop('Offer_location.2',axis=1,inplace=True)

# %%
for col in ['size','color','gender','bought']:
    df[col]=df[col].astype('category')
